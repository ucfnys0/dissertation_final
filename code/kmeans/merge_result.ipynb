# %%
import pandas as pd
import os
file1=r"..\..\result\predict.xlsx"
file2=r"..\..\result\kmeans_result_predict.xlsx"
file1_data=pd.read_excel(file1)
file2_data=pd.read_excel(file2)
data=pd.merge(file1_data,file2_data,on="LSOA code")

data
# Out:
#       LSOA code crime_score_x  final score final_label  Longitude   Latitude  \
# 0     E01000001     excellent      0.87180        good  -0.097334  51.521567
# 1     E01000002     excellent      0.87180        good  -0.090348  51.519358
# 2     E01000003     excellent      0.80885     average  -0.094468  51.521853
# 3     E01000005     excellent      0.74590     average  -0.073254  51.512856
# 4     E01000006     excellent      0.80885     average   0.088862  51.538218
# ...         ...           ...          ...         ...        ...        ...
# 4826  E01033742     excellent      0.80630     average   0.081374  51.496095
# 4827  E01033743     excellent      0.51495        fair   0.101985  51.504108
# 4828  E01033744     excellent      0.72890     average   0.079383  51.494124
# 4829  E01033745     excellent      0.51495        fair   0.105624  51.504591
# 4830  E01033746     excellent      0.84035     average  -0.012530  51.474576
#
#      crime_score_y poor_score health_score environment_score retail_score  \
# 0        excellent  excellent    excellent           average    excellent
# 1        excellent  excellent    excellent           average    excellent
# 2        excellent       good    excellent           average    excellent
# 3        excellent    average    excellent           average    excellent
# 4        excellent       good    excellent           average    excellent
# ...            ...        ...          ...               ...          ...
# 4826     excellent  excellent    excellent           average      average
# 4827     excellent       good      average           average      average
# 4828     excellent    average    excellent           average         good
# 4829     excellent       good      average           average      average
# 4830     excellent       good    excellent           average    excellent
#
#      air_label
# 0      average
# 1      average
# 2      average
# 3      average
# 4      average
# ...        ...
# 4826      good
# 4827      good
# 4828      good
# 4829      good
# 4830      good
#
# [4831 rows x 12 columns]

# %%
data.to_excel("..\..\result\kmeans_result.xlsx")
