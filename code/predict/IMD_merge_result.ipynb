# %%
import pandas as pd
import os
file1=r"..\..\dataset\IMD\preprocessed_IMD.xlsx"
file2=r"..\..\result\kmeans_result_predict.xlsx"
file1_data=pd.read_excel(file1)
file2_data=pd.read_excel(file2)
data=pd.merge(file1_data,file2_data,on="LSOA code")
data
# Out:
#       LSOA code poor_score_x  final score final_label  Longitude   Latitude  \
# 0     E01002388    excellent      0.72360     average   0.249199  51.546009
# 1     E01000810    excellent      0.80480     average   0.083405  51.387946
# 2     E01002253    excellent      0.60940     average   0.261404  51.570199
# 3     E01000688    excellent      0.67480     average   0.107487  51.356822
# 4     E01000815    excellent      0.80480     average   0.083697  51.392797
# ...         ...          ...          ...         ...        ...        ...
# 4826  E01002853      average      0.74590     average  -0.209150  51.521888
# 4827  E01000601      average      0.19420        poor  -0.252805  51.551061
# 4828  E01001178      average      0.58285        fair  -0.113939  51.390624
# 4829  E01002857      average      0.74590     average  -0.206735  51.525754
# 4830  E01002082      average      0.81010     average  -0.081640  51.597577
#
# ...

# %%
data.to_excel("..\..\result\kmeans_all.xlsx")
